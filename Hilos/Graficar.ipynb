# %%
# Importamos librerias
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Abrimos el archivo de los resultados en excel
resultados = pd.read_csv('resultadosfourier.csv',header=None)
ejeX = list(range(resultados.shape[0])) 

resultados
# Out:
#             0         1         2
# 0    2.558755 -2.266055  1.394426
# 1    2.763158 -3.165050  1.039431
# 2    2.988185 -2.879932  0.456552
# 3    3.076189  0.493611  0.180619
# 4    2.937585  3.258898  0.604058
# ..        ...       ...       ...
# 96   2.937585 -3.258898  0.604058
# 97   3.076189 -0.493611  0.180619
# 98   2.988185  2.879932  0.456552
# 99   2.763158  3.165050  1.039431
# 100  2.558755  2.266055  1.394426
#
# [101 rows x 3 columns]

# %%
# Abrimos los archivos generados por C
y1 = pd.read_csv('./y1.csv',header=None)
y2 = pd.read_csv('./y2.csv',header=None)
y3 = pd.read_csv('./y3.csv',header=None)

# Creamos una figura y un objeto que nos permite manipular los gráficos de la figura
fig, ax =  plt.subplots(3,2)
# Ajustamos el tamaño de la figura
fig.set_size_inches(16,12)
# Gráfico 1
ax[0,0].stem(ejeX, resultados[0],markerfmt='C0o', linefmt='C0-')
# Gráfico 2
ax[0,1].stem(ejeX, y1,markerfmt='C1o', linefmt='C1-')
# Gráfico 3
ax[1,0].stem(ejeX, resultados[1],markerfmt='C0o', linefmt='C0-')
# Gráfico 4
ax[1,1].stem(ejeX, y2,markerfmt='C1o', linefmt='C1-')
# Gráfico 5
ax[2,0].stem(ejeX, resultados[2],markerfmt='C0o', linefmt='C0-')
# Gráfico 6
ax[2,1].stem(ejeX, y3,markerfmt='C1o', linefmt='C1-')
# Mostramos el grafico
plt.show()

# %%
# Creamos una figura y un objeto que nos permite manipular los gráficos de la figura
fig, ax =  plt.subplots(3,2)
# Ajustamos el tamaño de la figura
fig.set_size_inches(16,12)
# Gráfico 1
ax[0,0].plot(ejeX, resultados[0], c = 'blue')
# Gráfico 2
ax[0,1].plot(ejeX, y1, c='red')
# Gráfico 3
ax[1,0].plot(ejeX, resultados[1], c = 'blue')
# Gráfico 4
ax[1,1].plot(ejeX, y2, c='red')
# Gráfico 5
ax[2,0].plot(ejeX, resultados[2], c = 'blue')
# Gráfico 6
ax[2,1].plot(ejeX, y3, c='red')
# Mostramos el grafico
plt.show()
